# %% [markdown]
# Aim:
# Data Wrangling II
# Create an “Academic performance” dataset of students and perform the following operations using Python.
# 1) Scan all variables for missing values and inconsistencies. If there are missing values and/or inconsistencies, use any of       the suitable techniques to deal with them.
# 2) Scan all numeric variables for outliers. If there are outliers, use any of the suitable techniques to deal with them.
# 3) Apply data transformations on at least one of the variables. The purpose of this transformation should be one of the            following reasons: to change the scale for better understanding of the variable, to convert a non-linear relation into a        linear one, or to decrease the skewness and convert the distribution into a normal distribution.

# %%
import pandas as pd

# %%
df = pd.read_csv('student.csv')

# %%
df
# Out:
#    roll     name class  marks   age
# 0     1     anil    TE  56.77  22.0
# 1     2     amit    TE  59.77  21.0
# 2     3   aniket    BE  76.88  19.0
# 3     4  ajunkya    TE  69.66   NaN
# 4     5     asha   NaN  63.28  20.0
# 5     6   ayesha   NaN  49.55  20.0
# 6     7     amar    BE    NaN  19.0
# 7     8    amita    BE    NaN  23.0
# 8     9     amol    TE  56.75  20.0
# 9    10    anmol    BE  78.66  21.0

# %%
df.isnull()
# Out:
#     roll   name  class  marks    age
# 0  False  False  False  False  False
# 1  False  False  False  False  False
# 2  False  False  False  False  False
# 3  False  False  False  False   True
# 4  False  False   True  False  False
# 5  False  False   True  False  False
# 6  False  False  False   True  False
# 7  False  False  False   True  False
# 8  False  False  False  False  False
# 9  False  False  False  False  False

# %%
df.isnull().sum()
# Out:
# roll     0
# name     0
# class    2
# marks    2
# age      1
# dtype: int64

# %%
df.dropna()
#drop all rows that having no value
# Out:
#    roll    name class  marks   age
# 0     1    anil    TE  56.77  22.0
# 1     2    amit    TE  59.77  21.0
# 2     3  aniket    BE  76.88  19.0
# 8     9    amol    TE  56.75  20.0
# 9    10   anmol    BE  78.66  21.0

# %%
df.fillna(0)
#identify missing value using domain knowledge....fill absed n domain knowledge
# Out:
#    roll     name class  marks   age
# 0     1     anil    TE  56.77  22.0
# 1     2     amit    TE  59.77  21.0
# 2     3   aniket    BE  76.88  19.0
# 3     4  ajunkya    TE  69.66   0.0
# 4     5     asha     0  63.28  20.0
# 5     6   ayesha     0  49.55  20.0
# 6     7     amar    BE   0.00  19.0
# 7     8    amita    BE   0.00  23.0
# 8     9     amol    TE  56.75  20.0
# 9    10    anmol    BE  78.66  21.0

# %%
#only using class column
df['class'].fillna('TE')
# Out:
# 0    TE
# 1    TE
# 2    BE
# 3    TE
# 4    TE
# 5    BE
# 6    BE
# 7    BE
# 8    TE
# 9    BE
# Name: class, dtype: object

# %%
df['marks'].fillna(df['marks'].mean())
# Out:
# 0    56.770
# 1    59.770
# 2    76.880
# 3    69.660
# 4    63.280
# 5    49.550
# 6    63.915
# 7    63.915
# 8    56.750
# 9    78.660
# Name: marks, dtype: float64

# %%
df['age'].fillna(df['age'].median())
# Out:
# 0    22.0
# 1    21.0
# 2    19.0
# 3    20.0
# 4    20.0
# 5    20.0
# 6    19.0
# 7    23.0
# 8    20.0
# 9    21.0
# Name: age, dtype: float64

# %%
df['class'].value_counts()
# Out:
# BE    5
# TE    4
# Name: class, dtype: int64

# %%
df.fillna(method='backfill')
# Out:
#    roll     name class  marks   age
# 0     1     anil    TE  56.77  22.0
# 1     2     amit    TE  59.77  21.0
# 2     3   aniket    BE  76.88  19.0
# 3     4  ajunkya    TE  69.66  20.0
# 4     5     asha    BE  63.28  20.0
# 5     6   ayesha    BE  49.55  20.0
# 6     7     amar    BE  56.75  19.0
# 7     8    amita    BE  56.75  23.0
# 8     9     amol    TE  56.75  20.0
# 9    10    anmol    BE  78.66  21.0

# %%
df
# Out:
#    roll     name class  marks   age
# 0     1     anil    TE  56.77  22.0
# 1     2     amit    TE  59.77  21.0
# 2     3   aniket    BE  76.88  19.0
# 3     4  ajunkya    TE  69.66   NaN
# 4     5     asha   NaN  63.28  20.0
# 5     6   ayesha    BE  49.55  20.0
# 6     7     amar    BE    NaN  19.0
# 7     8    amita    BE    NaN  23.0
# 8     9     amol    TE  56.75  20.0
# 9    10    anmol    BE  78.66  21.0

# %%
df.fillna(method='pad')
# Out:
#    roll     name class  marks   age
# 0     1     anil    TE  56.77  22.0
# 1     2     amit    TE  59.77  21.0
# 2     3   aniket    BE  76.88  19.0
# 3     4  ajunkya    TE  69.66  19.0
# 4     5     asha    TE  63.28  20.0
# 5     6   ayesha    BE  49.55  20.0
# 6     7     amar    BE  49.55  19.0
# 7     8    amita    BE  49.55  23.0
# 8     9     amol    TE  56.75  20.0
# 9    10    anmol    BE  78.66  21.0

# %%
import numpy as np
x = np.array([5,4,3,2,7,8,98,28])

# %%
np.mean(x)
# Out:
# 19.375

# %%
np.median(x)
# Out:
# 6.0

# %%
df.loc[6,'marks']
# Out:
# nan

# %%
df.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
x= df[['age','marks']]

# %%
x.describe()
# Out:
#              age      marks
# count   9.000000   8.000000
# mean   20.555556  63.915000
# std     1.333333  10.315294
# min    19.000000  49.550000
# 25%    20.000000  56.765000
# 50%    20.000000  61.525000
# 75%    21.000000  71.465000
# max    23.000000  78.660000

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#               0         1
# count  9.000000  8.000000
# mean   0.388889  0.493473
# std    0.333333  0.354356
# min    0.000000  0.000000
# 25%    0.250000  0.247853
# 50%    0.250000  0.411371
# 75%    0.500000  0.752834
# max    1.000000  1.000000

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
pd.DataFrame(x_scaled).describe()
# Out:
#                   0             1
# count  9.000000e+00  8.000000e+00
# mean  -1.276756e-15  6.938894e-16
# std    1.060660e+00  1.069045e+00
# min   -1.237437e+00 -1.488744e+00
# 25%   -4.419417e-01 -7.410038e-01
# 50%   -4.419417e-01 -2.476922e-01
# 75%    3.535534e-01  7.824585e-01
# max    1.944544e+00  1.528126e+00
